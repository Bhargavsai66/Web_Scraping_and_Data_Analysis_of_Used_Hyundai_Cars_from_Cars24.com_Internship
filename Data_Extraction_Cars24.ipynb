# %%
# Import necessary Selenium and Python modules
from selenium import webdriver  # Controls the browser
from selenium.webdriver.common.by import By  # Allows selection of elements by tag, class, etc.
from selenium.webdriver.chrome.service import Service  # Manages ChromeDriver service
from selenium.webdriver.chrome.options import Options  # Configures browser settings
from selenium.webdriver.support.ui import WebDriverWait  # Waits for elements to load
from selenium.webdriver.support import expected_conditions as EC  # Defines wait conditions
import pandas as pd  # For storing and exporting data
import time  # For sleep delays
import random  # For randomized retry delays
 
# -------------------------------
# Setup Chrome WebDriver options
# -------------------------------
options = Options()
options.add_argument("--start-maximized")  # Open browser maximized for proper rendering
options.add_argument("--disable-gpu")      # Disable GPU acceleration
options.add_argument("--window-size=1920,1080")  # Set fixed window size
# options.add_argument("--headless")  # Headless mode may prevent dynamic content loading

# Initialize WebDriver with options
driver = webdriver.Chrome(service=Service(), options=options)
wait = WebDriverWait(driver, 10)  # Wait up to 10 seconds for elements to appear

# -------------------------------
# Step 1: Collect all car listing URLs via scrolling
# -------------------------------
base_url = "https://www.cars24.com/buy-used-hyundai-cars-mumbai/?sort=bestmatch&storeCityId=2378"
driver.get(base_url)  # Open the main page
time.sleep(5)  # Wait for initial page load

car_urls = []        # Master list to store all unique car URLs
seen_urls = set()    # Set to track already seen URLs to avoid duplicates
last_count = 0       # Number of car elements in the previous scroll
same_count_rounds = 0  # Count consecutive scrolls with no new cars

while True:
    # Scroll to the bottom of the page to trigger dynamic loading
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)  # Wait for newly loaded cars to appear

    # Find all currently visible car cards on the page
    car_elements = driver.find_elements(By.CLASS_NAME, "styles_carCardWrapper__sXLIp")
    urls = [car.get_attribute("href") for car in car_elements if car.get_attribute("href")]

    # Filter out duplicates
    new_urls = [u for u in urls if u not in seen_urls]
    seen_urls.update(new_urls)  # Add newly found URLs to the seen set
    car_urls.extend(new_urls)   # Add to the master list

    # Log progress
    print(f"Currently visible cars: {len(car_elements)} | Collected unique: {len(car_urls)}")

    # Check if no new cars appeared in this scroll
    if len(car_elements) == last_count:
        same_count_rounds += 1  # Increment counter for consecutive identical scrolls
    else:
        same_count_rounds = 0  # Reset if new cars were found

    last_count = len(car_elements)  # Update last count

    # Stop scrolling if bottom reached (3 consecutive scrolls with no new cars)
    if same_count_rounds >= 3:
        print("Reached bottom of the listings.")
        break

print(f"\nTotal unique car URLs collected: {len(car_urls)}\n")

# -------------------------------
# Step 2: Visit each car page and extract details
# -------------------------------
carList = []  # List to store each car's data as a dictionary

for idx, car_url in enumerate(car_urls):
    for attempt in range(3):  # Retry up to 3 times if scraping fails
        try:
            driver.get(car_url)  # Open car detail page
            time.sleep(2)  # Wait for page load

            # Extract main details: model, location, price
            car_model = wait.until(
                EC.presence_of_element_located((By.CLASS_NAME, "styles_carName__xzcd4"))
            ).text
            location = wait.until(
                EC.presence_of_element_located((By.CLASS_NAME, "styles_carLocation__UrZVn"))
            ).text
            price = wait.until(
                EC.presence_of_element_located((By.CLASS_NAME, "styles_price__3yE9i"))
            ).text.split("\n")

            # Store main details in a dictionary
            carData = {
                "Car Model": car_model,
                "Location": location,
                "Price": price[0]
            }

            # Extract "Know Your Car" specs
            specs_section = wait.until(
                EC.presence_of_element_located((By.ID, "CATALOG_CDP_KNOW_YOUR_CAR"))
            )
            specs_container = specs_section.find_elements(By.CLASS_NAME, "styles_content__KtXDs")[0]
            specs_items = specs_container.find_elements(By.TAG_NAME, "p")  # All <p> tags (labels + values)

            # Loop through specs to extract relevant info
            for i in range(len(specs_items) - 1):
                key = specs_items[i].text.strip()
                value = specs_items[i + 1].text.strip()
                if key in ["Fuel", "KM driven", "Transmission"]:
                    carData[key] = value

            # Log car data and add to master list
            print(f"Option {idx}: {carData}")
            carList.append(carData)
            break  # Exit retry loop on success

        except Exception as e:
            print(f"Attempt {attempt + 1} failed for car {idx}: {e}")
            time.sleep(random.uniform(1, 3))  # Wait a random interval before retry

# -------------------------------
# Step 3: Save all scraped data to a CSV file
# -------------------------------
df = pd.DataFrame(carList)  # Convert list of dictionaries to DataFrame
df.to_csv("hyundai_cars_mumbai.csv", index=False)  # Save as CSV
print(f"\nAll {len(carList)} cars saved to 'hyundai_cars_mumbai.csv'")

# -------------------------------
# Step 4: Close the browser session
# -------------------------------
driver.quit()  # Shut down the browser
# Out:
# Currently visible cars: 120 | Collected unique: 120
# Currently visible cars: 291 | Collected unique: 291
# Currently visible cars: 291 | Collected unique: 291
# Currently visible cars: 291 | Collected unique: 291
# Currently visible cars: 291 | Collected unique: 291
# Reached bottom of the listings.
#
# Total unique car URLs collected: 291
#
# Option 0: {'Car Model': '2019 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Goregaon, Mumbai', 'Price': '₹3.55 lakh', 'Fuel': 'CNG', 'KM driven': '82,657 km', 'Transmission': 'Manual'}
# Option 1: {'Car Model': '2016 Hyundai Elite i20 SPORTZ 1.2', 'Location': 'Goregaon, Mumbai', 'Price': '₹3.24 lakh', 'Fuel': 'Petrol', 'KM driven': '82,473 km', 'Transmission': 'Manual'}
# Option 2: {'Car Model': '2021 Hyundai AURA S 1.2 CNG', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹5.8 lakh', 'Fuel': 'CNG', 'KM driven': '6,916 km', 'Transmission': 'Manual'}
# Option 3: {'Car Model': '2022 Hyundai AURA S 1.2 CNG', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹6.5 lakh', 'Fuel': 'CNG', 'KM driven': '9,976 km', 'Transmission': 'Manual'}
# Option 4: {'Car Model': '2022 Hyundai NEW I20 N LINE N6 1.0 TURBO GDI IMT', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹8.7 lakh', 'Fuel': 'Petrol', 'KM driven': '28,611 km', 'Transmission': 'Manual'}
# Option 5: {'Car Model': '2017 Hyundai Xcent E+', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹3.9 lakh', 'Fuel': 'Petrol', 'KM driven': '103,048 km', 'Transmission': 'Manual'}
# Option 6: {'Car Model': '2013 Hyundai Eon MAGNA +', 'Location': 'Thakur Village Kandivali E Mumbai', 'Price': '₹2.3 lakh', 'Fuel': 'Petrol', 'KM driven': '47,062 km', 'Transmission': 'Manual'}
# Option 7: {'Car Model': '2014 Hyundai Eon D-LITE+', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹2 lakh', 'Fuel': 'Petrol', 'KM driven': '38,085 km', 'Transmission': 'Manual'}
# Option 8: {'Car Model': '2021 Hyundai NEW I20 ASTA (O) 1.0 TURBO GDI DCT', 'Location': 'Korum Mall, Thane West', 'Price': '₹8.43 lakh', 'Fuel': 'Petrol', 'KM driven': '31,681 km', 'Transmission': 'Automatic'}
# Option 9: {'Car Model': '2024 Hyundai AURA S 1.2', 'Location': 'Thakur Village Kandivali E Mumbai', 'Price': '₹6.35 lakh', 'Fuel': 'Petrol', 'KM driven': '28,849 km', 'Transmission': 'Manual'}
# Option 10: {'Car Model': '2017 Hyundai Creta SX PLUS 1.6 DIESEL SPECIAL EDITION', 'Location': 'Seawood', 'Price': '₹7.41 lakh', 'Fuel': 'Diesel', 'KM driven': '76,209 km', 'Transmission': 'Manual'}
# Option 11: {'Car Model': '2017 Hyundai Grand i10 ASTA 1.2 KAPPA VTVT', 'Location': 'Thakur Village Kandivali E Mumbai', 'Price': '₹3.81 lakh', 'Fuel': 'Petrol', 'KM driven': '14,157 km', 'Transmission': 'Manual'}
# Option 12: {'Car Model': '2020 Hyundai Creta SX (O) IVT 1.5 PETROL', 'Location': 'Mulund West, Mumbai', 'Price': '₹10.95 lakh', 'Fuel': 'Petrol', 'KM driven': '61,632 km', 'Transmission': 'Automatic'}
# Option 13: {'Car Model': '2018 Hyundai Elite i20 ASTA 1.2', 'Location': 'Goregaon, Mumbai', 'Price': '₹4.8 lakh', 'Fuel': 'Petrol', 'KM driven': '67,874 km', 'Transmission': 'Manual'}
# Option 14: {'Car Model': '2012 Hyundai i20 MAGNA 1.2', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹1.93 lakh', 'Fuel': 'Petrol', 'KM driven': '147,671 km', 'Transmission': 'Manual'}
# Option 15: {'Car Model': '2019 Hyundai NEW SANTRO SPORTZ AMT', 'Location': 'Thakur Village Kandivali E Mumbai', 'Price': '₹3.71 lakh', 'Fuel': 'Petrol', 'KM driven': '62,306 km', 'Transmission': 'Automatic'}
# Option 16: {'Car Model': '2017 Hyundai Creta SX PLUS AT 1.6 PETROL', 'Location': 'Goregaon, Mumbai', 'Price': '₹6.41 lakh', 'Fuel': 'Petrol', 'KM driven': '148,517 km', 'Transmission': 'Automatic'}
# Option 17: {'Car Model': '2018 Hyundai Creta E PLUS 1.6 PETROL', 'Location': 'Goregaon, Mumbai', 'Price': '₹5.89 lakh', 'Fuel': 'Petrol', 'KM driven': '89,207 km', 'Transmission': 'Manual'}
# Option 18: {'Car Model': '2019 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Korum Mall, Thane West', 'Price': '₹3.75 lakh', 'Fuel': 'CNG', 'KM driven': '85,579 km', 'Transmission': 'Manual'}
# Option 19: {'Car Model': '2021 Hyundai AURA S 1.2', 'Location': 'Seawood', 'Price': '₹5.71 lakh', 'Fuel': 'CNG', 'KM driven': '50,856 km', 'Transmission': 'Manual'}
# Option 20: {'Car Model': '2014 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Korum Mall, Thane West', 'Price': '₹2.65 lakh', 'Fuel': 'Petrol', 'KM driven': '56,428 km', 'Transmission': 'Manual'}
# Option 21: {'Car Model': '2020 Hyundai NEW I20 ASTA 1.0 GDI TURBO DCT', 'Location': 'Goregaon, Mumbai', 'Price': '₹7 lakh', 'Fuel': 'Petrol', 'KM driven': '71,197 km', 'Transmission': 'Automatic'}
# Option 22: {'Car Model': '2018 Hyundai NEW SANTRO SPORTZ MT', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹3.2 lakh', 'Fuel': 'Petrol', 'KM driven': '39,944 km', 'Transmission': 'Manual'}
# Option 23: {'Car Model': '2022 Hyundai VENUE S+ 1.2', 'Location': 'Mulund West, Mumbai', 'Price': '₹7.06 lakh', 'Fuel': 'Petrol', 'KM driven': '34,022 km', 'Transmission': 'Manual'}
# Option 24: {'Car Model': '2013 Hyundai i10 ASTA 1.2 AT SUNROOF', 'Location': 'Goregaon, Mumbai', 'Price': '₹2.53 lakh', 'Fuel': 'Petrol', 'KM driven': '31,273 km', 'Transmission': 'Automatic'}
# Option 25: {'Car Model': '2021 Hyundai NEW SANTRO SPORTZ EXECUTIVE MT CNG', 'Location': 'Goregaon, Mumbai', 'Price': '₹3.79 lakh', 'Fuel': 'CNG', 'KM driven': '82,360 km', 'Transmission': 'Manual'}
# Option 26: {'Car Model': '2016 Hyundai Creta SX PLUS 1.6 PETROL', 'Location': 'Goregaon, Mumbai', 'Price': '₹6.21 lakh', 'Fuel': 'CNG', 'KM driven': '88,646 km', 'Transmission': 'Manual'}
# Option 27: {'Car Model': '2015 Hyundai Elite i20 SPORTZ 1.4 CRDI', 'Location': 'Thakur Village Kandivali E Mumbai', 'Price': '₹4.59 lakh', 'Fuel': 'Diesel', 'KM driven': '41,547 km', 'Transmission': 'Manual'}
# Option 28: {'Car Model': '2022 Hyundai GRAND I10 NIOS ASTA AMT 1.2 KAPPA VTVT', 'Location': 'Mulund West, Mumbai', 'Price': '₹6.61 lakh', 'Fuel': 'Petrol', 'KM driven': '34,018 km', 'Transmission': 'Automatic'}
# Option 29: {'Car Model': '2012 Hyundai i20 SPORTZ 1.2', 'Location': 'Goregaon, Mumbai', 'Price': '₹2.31 lakh', 'Fuel': 'Petrol', 'KM driven': '76,651 km', 'Transmission': 'Manual'}
# Option 30: {'Car Model': '2018 Hyundai Elite i20 MAGNA EXECUTIVE CVT', 'Location': 'Seawood', 'Price': '₹5.61 lakh', 'Fuel': 'Petrol', 'KM driven': '26,607 km', 'Transmission': 'Automatic'}
# Option 31: {'Car Model': '2019 Hyundai Creta S 1.4 DIESEL', 'Location': 'Mulund West, Mumbai', 'Price': '₹8.62 lakh', 'Fuel': 'Diesel', 'KM driven': '81,304 km', 'Transmission': 'Manual'}
# Option 32: {'Car Model': '2018 Hyundai Creta SX PLUS AT 1.6 PETROL', 'Location': 'Thakur Village Kandivali E Mumbai', 'Price': '₹7.25 lakh', 'Fuel': 'Petrol', 'KM driven': '56,007 km', 'Transmission': 'Automatic'}
# Option 33: {'Car Model': '2020 Hyundai AURA SX PLUS 1.2 AMT CRDI', 'Location': 'Goregaon, Mumbai', 'Price': '₹6.5 lakh', 'Fuel': 'Diesel', 'KM driven': '57,572 km', 'Transmission': 'Automatic'}
# Option 34: {'Car Model': '2020 Hyundai VENUE SX 1.0 TURBO IMT', 'Location': 'Seawood', 'Price': '₹7.27 lakh', 'Fuel': 'Petrol', 'KM driven': '63,694 km', 'Transmission': 'Manual'}
# Option 35: {'Car Model': '2014 Hyundai i10 SPORTZ 1.1', 'Location': 'Mulund West, Mumbai', 'Price': '₹2.11 lakh', 'Fuel': 'Petrol', 'KM driven': '46,962 km', 'Transmission': 'Manual'}
# Option 36: {'Car Model': '2023 Hyundai EXTER SX 1.2 AMT', 'Location': 'Korum Mall, Thane West', 'Price': '₹8 lakh', 'Fuel': 'Petrol', 'KM driven': '6,842 km', 'Transmission': 'Automatic'}
# Option 37: {'Car Model': '2017 Hyundai Grand i10 MAGNA AT 1.2 KAPPA VTVT', 'Location': 'Seawood', 'Price': '₹4.25 lakh', 'Fuel': 'Petrol', 'KM driven': '52,993 km', 'Transmission': 'Automatic'}
# Option 38: {'Car Model': '2013 Hyundai i10 MAGNA 1.1', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹2.12 lakh', 'Fuel': 'Petrol', 'KM driven': '17,870 km', 'Transmission': 'Manual'}
# Option 39: {'Car Model': '2017 Hyundai i20 Active 1.2 SX', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹4.91 lakh', 'Fuel': 'Petrol', 'KM driven': '45,038 km', 'Transmission': 'Manual'}
# Option 40: {'Car Model': '2014 Hyundai Grand i10 ASTA 1.2 KAPPA VTVT', 'Location': 'Seawood', 'Price': '₹3.21 lakh', 'Fuel': 'Petrol', 'KM driven': '19,032 km', 'Transmission': 'Manual'}
# Option 41: {'Car Model': '2015 Hyundai Grand i10 ASTA AT 1.2 KAPPA VTVT', 'Location': 'Mulund West, Mumbai', 'Price': '₹3.25 lakh', 'Fuel': 'Petrol', 'KM driven': '60,158 km', 'Transmission': 'Automatic'}
# Option 42: {'Car Model': '2019 Hyundai Creta SX 1.6 DIESEL', 'Location': 'Goregaon, Mumbai', 'Price': '₹9.29 lakh', 'Fuel': 'Diesel', 'KM driven': '93,081 km', 'Transmission': 'Manual'}
# Option 43: {'Car Model': '2015 Hyundai Verna FLUIDIC 1.6 CRDI SX 4S', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹5.76 lakh', 'Fuel': 'Diesel', 'KM driven': '62,607 km', 'Transmission': 'Manual'}
# Option 44: {'Car Model': '2017 Hyundai Elite i20 SPORTZ 1.2', 'Location': 'Seawood', 'Price': '₹4.06 lakh', 'Fuel': 'Petrol', 'KM driven': '54,098 km', 'Transmission': 'Manual'}
# Option 45: {'Car Model': '2020 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT', 'Location': 'Goregaon, Mumbai', 'Price': '₹5.05 lakh', 'Fuel': 'Petrol', 'KM driven': '46,043 km', 'Transmission': 'Manual'}
# Option 46: {'Car Model': '2023 Hyundai ALCAZAR PRESTIGE 1.5 TURBO PETROL MT 7STR', 'Location': 'Goregaon, Mumbai', 'Price': '₹14.61 lakh', 'Fuel': 'Petrol', 'KM driven': '22,730 km', 'Transmission': 'Manual'}
# Option 47: {'Car Model': '2021 Hyundai AURA SX 1.2', 'Location': 'Korum Mall, Thane West', 'Price': '₹5.85 lakh', 'Fuel': 'Petrol', 'KM driven': '13,104 km', 'Transmission': 'Manual'}
# Option 48: {'Car Model': '2018 Hyundai New Elantra 2.0 SX(O) AT PETROL', 'Location': 'Mulund West, Mumbai', 'Price': '₹7.42 lakh', 'Fuel': 'Petrol', 'KM driven': '93,341 km', 'Transmission': 'Automatic'}
# Option 49: {'Car Model': '2015 Hyundai i10 MAGNA 1.1', 'Location': 'Mulund West, Mumbai', 'Price': '₹2.57 lakh', 'Fuel': 'Petrol', 'KM driven': '76,630 km', 'Transmission': 'Manual'}
# Option 50: {'Car Model': '2018 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT DUAL TONE', 'Location': 'Goregaon, Mumbai', 'Price': '₹3.85 lakh', 'Fuel': 'Petrol', 'KM driven': '46,099 km', 'Transmission': 'Manual'}
# Option 51: {'Car Model': '2018 Hyundai Xcent S 1.2', 'Location': 'Goregaon, Mumbai', 'Price': '₹4.5 lakh', 'Fuel': 'Petrol', 'KM driven': '100,881 km', 'Transmission': 'Manual'}
# Option 52: {'Car Model': '2016 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Mulund West, Mumbai', 'Price': '₹3.68 lakh', 'Fuel': 'Petrol', 'KM driven': '47,592 km', 'Transmission': 'Manual'}
# Option 53: {'Car Model': '2023 Hyundai AURA SX 1.2', 'Location': 'Goregaon, Mumbai', 'Price': '₹6.85 lakh', 'Fuel': 'Petrol', 'KM driven': '7,288 km', 'Transmission': 'Manual'}
# Option 54: {'Car Model': '2015 Hyundai Elite i20 SPORTZ 1.2 (O)', 'Location': 'Goregaon, Mumbai', 'Price': '₹3.89 lakh', 'Fuel': 'Petrol', 'KM driven': '73,898 km', 'Transmission': 'Manual'}
# Option 55: {'Car Model': '2022 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹5.57 lakh', 'Fuel': 'Petrol', 'KM driven': '28,068 km', 'Transmission': 'Manual'}
# Option 56: {'Car Model': '2023 Hyundai NEW I20 N LINE N8 1.0 TURBO DCT', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹9.81 lakh', 'Fuel': 'Petrol', 'KM driven': '18,996 km', 'Transmission': 'Automatic'}
# Option 57: {'Car Model': '2016 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Korum Mall, Thane West', 'Price': '₹3.65 lakh', 'Fuel': 'Petrol', 'KM driven': '58,285 km', 'Transmission': 'Manual'}
# Option 58: {'Car Model': '2012 Hyundai Eon SPORTZ', 'Location': 'Powai Mumbai Maharashtra', 'Price': '₹1.4 lakh', 'Fuel': 'Petrol', 'KM driven': '43,869 km', 'Transmission': 'Manual'}
# Option 59: {'Car Model': '2013 Hyundai i10 MAGNA 1.1', 'Location': 'Pancharatna Complex 2WXQ+GX Mumbai Maharashtra', 'Price': '₹1.83 lakh', 'Fuel': 'Petrol', 'KM driven': '31,484 km', 'Transmission': 'Manual'}
# Option 60: {'Car Model': '2013 Hyundai Verna FLUIDIC 1.6 VTVT EX', 'Location': 'Kandivali East Mumbai Maharashtra', 'Price': '₹2.92 lakh', 'Fuel': 'Petrol', 'KM driven': '14,404 km', 'Transmission': 'Manual'}
# Option 61: {'Car Model': '2013 Hyundai i20 MAGNA 1.2', 'Location': 'Kandivali West Mumbai Maharashtra', 'Price': '₹3.52 lakh', 'Fuel': 'Petrol', 'KM driven': '21,806 km', 'Transmission': 'Manual'}
# Option 62: {'Car Model': '2011 Hyundai i20 ASTA 1.2', 'Location': 'Kharghar Navi Mumbai Maharashtra', 'Price': '₹1.4 lakh', 'Fuel': 'Petrol', 'KM driven': '88,618 km', 'Transmission': 'Manual'}
# Option 63: {'Car Model': '2011 Hyundai i20 SPORTZ 1.4 CRDI', 'Location': 'Sector 32 Gurugram', 'Price': '₹1.65 lakh', 'Fuel': 'Diesel', 'KM driven': '76,146 km', 'Transmission': 'Manual'}
# Option 64: {'Car Model': '2019 Hyundai Elite i20 MAGNA PLUS 1.2', 'Location': 'Kandivali West Mumbai Maharashtra', 'Price': '₹4.74 lakh', 'Fuel': 'Petrol', 'KM driven': '23,438 km', 'Transmission': 'Manual'}
# Option 65: {'Car Model': '2017 Hyundai Verna 1.6 VTVT SX O', 'Location': 'Navare Nagar Ambernath Maharashtra', 'Price': '₹5.93 lakh', 'Fuel': 'Petrol', 'KM driven': '77,191 km', 'Transmission': 'Manual'}
# Option 66: {'Car Model': '2018 Hyundai Elite i20 MAGNA EXECUTIVE 1.2', 'Location': 'Antop Hill Mumbai Maharashtra', 'Price': '₹3.83 lakh', 'Fuel': 'Petrol', 'KM driven': '41,688 km', 'Transmission': 'Manual'}
# Option 67: {'Car Model': '2015 Hyundai i10 MAGNA 1.1', 'Location': 'Thane East Thane Maharashtra', 'Price': '₹2.73 lakh', 'Fuel': 'Petrol', 'KM driven': '62,661 km', 'Transmission': 'Manual'}
# Option 68: {'Car Model': '2016 Hyundai Elite i20 SPORTZ 1.2', 'Location': 'Khadakpada Kalyan Maharashtra', 'Price': '₹3.58 lakh', 'Fuel': 'Petrol', 'KM driven': '67,896 km', 'Transmission': 'Manual'}
# Option 69: {'Car Model': '2011 Hyundai Verna FLUIDIC 1.6 VTVT SX', 'Location': 'Santosh Nagar Kalyan Maharashtra', 'Price': '₹1.82 lakh', 'Fuel': 'Petrol', 'KM driven': '63,304 km', 'Transmission': 'Manual'}
# Option 70: {'Car Model': '2011 Hyundai i20 SPORTZ 1.2', 'Location': 'Kandivali West Mumbai Maharashtra', 'Price': '₹1.61 lakh', 'Fuel': 'Petrol', 'KM driven': '71,203 km', 'Transmission': 'Manual'}
# Option 71: {'Car Model': '2016 Hyundai Creta SX PLUS 1.6 PETROL', 'Location': 'Kandivali East Mumbai Maharashtra', 'Price': '₹6.52 lakh', 'Fuel': 'Petrol', 'KM driven': '44,499 km', 'Transmission': 'Manual'}
# Option 72: {'Car Model': '2010 Hyundai i10 ASTA 1.2', 'Location': 'Bhandup West Mumbai Maharashtra', 'Price': '₹1.23 lakh', 'Fuel': 'Petrol', 'KM driven': '78,517 km', 'Transmission': 'Manual'}
# Option 73: {'Car Model': '2010 Hyundai i20 ASTA 1.2', 'Location': 'Sanpada Navi Mumbai Maharashtra', 'Price': '₹1.39 lakh', 'Fuel': 'Petrol', 'KM driven': '104,801 km', 'Transmission': 'Manual'}
# Option 74: {'Car Model': '2021 Hyundai NEW I20 SPORTZ 1.2 MT', 'Location': 'Syndicate Kalyan Maharashtra', 'Price': '₹5.79 lakh', 'Fuel': 'Petrol', 'KM driven': '21,417 km', 'Transmission': 'Manual'}
# Option 75: {'Car Model': '2019 Hyundai NEW SANTRO SPORTZ CNG', 'Location': 'Kailash Colony Ulhasnagar Maharashtra', 'Price': '₹3.6 lakh', 'Fuel': 'Petrol', 'KM driven': '67,125 km', 'Transmission': 'Manual'}
# Option 76: {'Car Model': '2015 Hyundai Elite i20 ASTA 1.2', 'Location': 'Khadakpada Kalyan Maharashtra', 'Price': '₹3.73 lakh', 'Fuel': 'Petrol', 'KM driven': '75,830 km', 'Transmission': 'Manual'}
# Option 77: {'Car Model': '2017 Hyundai Verna 1.6 VTVT SX (O) AT', 'Location': 'Khar West Mumbai', 'Price': '₹7.54 lakh', 'Fuel': 'Petrol', 'KM driven': '23,780 km', 'Transmission': 'Automatic'}
# Option 78: {'Car Model': '2013 Hyundai i20 SPORTZ 1.2', 'Location': 'Powai Mumbai Maharashtra', 'Price': '₹2.09 lakh', 'Fuel': 'Petrol', 'KM driven': '32,560 km', 'Transmission': 'Manual'}
# Option 79: {'Car Model': '2015 Hyundai Elite i20 ASTA 1.4 CRDI', 'Location': 'Mumbra Thane Maharashtra', 'Price': '₹4.24 lakh', 'Fuel': 'Diesel', 'KM driven': '153,594 km', 'Transmission': 'Manual'}
# Option 80: {'Car Model': '2013 Hyundai i20 ASTA 1.2', 'Location': 'N.M Joshi Marg Lower Parel Mumbai', 'Price': '₹1.86 lakh', 'Fuel': 'Petrol', 'KM driven': '82,775 km', 'Transmission': 'Manual'}
# Option 81: {'Car Model': '2013 Hyundai i10 SPORTZ 1.2 AT', 'Location': 'Mira Road East Mira Bhayandar Maharashtra', 'Price': '₹1.94 lakh', 'Fuel': 'Petrol', 'KM driven': '74,277 km', 'Transmission': 'Automatic'}
# Option 82: {'Car Model': '2021 Hyundai AURA S 1.2 CNG', 'Location': 'Kailash Colony Ulhasnagar Maharashtra', 'Price': '₹5 lakh', 'Fuel': 'Petrol', 'KM driven': '53,216 km', 'Transmission': 'Manual'}
# Option 83: {'Car Model': '2012 Hyundai i20 SPORTZ 1.2', 'Location': 'Vashi Navi Mumbai Maharashtra', 'Price': '₹2.49 lakh', 'Fuel': 'Petrol', 'KM driven': '61,903 km', 'Transmission': 'Manual'}
# Option 84: {'Car Model': '2012 Hyundai i10 SPORTZ 1.2', 'Location': 'MGM Residency Ulwe Sector 19 Navi Mumbai', 'Price': '₹1.61 lakh', 'Fuel': 'Petrol', 'KM driven': '46,285 km', 'Transmission': 'Manual'}
# Option 85: {'Car Model': '2020 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT', 'Location': 'Paisar Barabanki', 'Price': '₹3.99 lakh', 'Fuel': 'Petrol', 'KM driven': '75,599 km', 'Transmission': 'Manual'}
# Option 86: {'Car Model': '2024 Hyundai NEW I20 SPORTZ 1.2 IVT', 'Location': 'Thane West Mumbai', 'Price': '₹8.49 lakh', 'Fuel': 'Petrol', 'KM driven': '15,175 km', 'Transmission': 'Automatic'}
# Option 87: {'Car Model': '2014 Hyundai Eon MAGNA +', 'Location': 'Virar East Virar Maharashtra', 'Price': '₹1.66 lakh', 'Fuel': 'Petrol', 'KM driven': '35,122 km', 'Transmission': 'Manual'}
# Option 88: {'Car Model': '2024 Hyundai Creta E 1.5 PETROL', 'Location': 'Lohegaon Pune', 'Price': '₹11.77 lakh', 'Fuel': 'Petrol', 'KM driven': '5,398 km', 'Transmission': 'Manual'}
# Option 89: {'Car Model': '2013 Hyundai i10 SPORTZ 1.1 LPG', 'Location': 'Panvel Navi Mumbai', 'Price': '₹2.19 lakh', 'Fuel': 'Petrol', 'KM driven': '51,441 km', 'Transmission': 'Manual'}
# Option 90: {'Car Model': '2013 Hyundai i10 ASTA 1.2', 'Location': 'Virar West Vasai-Virar Maharashtra', 'Price': '₹1.74 lakh', 'Fuel': 'Petrol', 'KM driven': '42,771 km', 'Transmission': 'Manual'}
# Option 91: {'Car Model': '2017 Hyundai Grand i10 SPORTZ (O) AT 1.2 KAPPA VTVT', 'Location': 'Khemani Industry Area Ulhasnagar Maharashtra', 'Price': '₹3 lakh', 'Fuel': 'Petrol', 'KM driven': '42,884 km', 'Transmission': 'Automatic'}
# Option 92: {'Car Model': '2012 Hyundai i10 MAGNA 1.2', 'Location': 'Goregaon Mumbai', 'Price': '₹1.37 lakh', 'Fuel': 'Petrol', 'KM driven': '41,288 km', 'Transmission': 'Manual'}
# Option 93: {'Car Model': '2012 Hyundai Verna FLUIDIC 1.6 CRDI SX', 'Location': 'वसई वेस्ट तारखाड', 'Price': '₹2.31 lakh', 'Fuel': 'Diesel', 'KM driven': '90,002 km', 'Transmission': 'Manual'}
# Option 94: {'Car Model': '2020 Hyundai Creta SX 1.5 PETROL', 'Location': 'Kaneri Bhiwandi', 'Price': '₹9 lakh', 'Fuel': 'Petrol', 'KM driven': '66,726 km', 'Transmission': 'Manual'}
# Option 95: {'Car Model': '2018 Hyundai Elite i20 ASTA 1.2 DUAL TONE', 'Location': 'Seawoods Navi Mumbai Maharashtra', 'Price': '₹4.13 lakh', 'Fuel': 'Petrol', 'KM driven': '115,900 km', 'Transmission': 'Manual'}
# Option 96: {'Car Model': '2017 Hyundai Grand i10 MAGNA 1.2 KAPPA VTVT', 'Location': 'Taloja Navi Mumbai Maharashtra', 'Price': '₹3.23 lakh', 'Fuel': 'Petrol', 'KM driven': '71,942 km', 'Transmission': 'Manual'}
# Option 97: {'Car Model': '2014 Hyundai Grand i10 ASTA 1.2 KAPPA VTVT', 'Location': 'Prabhadevi Mumbai Maharashtra', 'Price': '₹2.25 lakh', 'Fuel': 'Petrol', 'KM driven': '88,257 km', 'Transmission': 'Manual'}
# Option 98: {'Car Model': '2012 Hyundai i10 ERA 1.1', 'Location': 'Ulwe Navi Mumbai', 'Price': '₹2.29 lakh', 'Fuel': 'Petrol', 'KM driven': '36,625 km', 'Transmission': 'Manual'}
# Option 99: {'Car Model': '2010 Hyundai i10 MAGNA 1.1', 'Location': 'Vile Parle Mumbai', 'Price': '₹0.98 lakh', 'Fuel': 'Petrol', 'KM driven': '23,000 km', 'Transmission': 'Manual'}
# Option 100: {'Car Model': '2012 Hyundai Verna FLUIDIC 1.6 VTVT SX', 'Location': 'Kalwa Thane Maharashtra', 'Price': '₹2.66 lakh', 'Fuel': 'Petrol', 'KM driven': '76,888 km', 'Transmission': 'Manual'}
# Option 101: {'Car Model': '2017 Hyundai Elite i20 ASTA 1.2', 'Location': 'Chembur Mumbai Maharashtra', 'Price': '₹3.92 lakh', 'Fuel': 'Petrol', 'KM driven': '71,310 km', 'Transmission': 'Manual'}
# Option 102: {'Car Model': '2016 Hyundai i10 SPORTZ 1.1', 'Location': 'Sector 32 Gurugram', 'Price': '₹2.13 lakh', 'Fuel': 'Petrol', 'KM driven': '76,529 km', 'Transmission': 'Manual'}
# Option 103: {'Car Model': '2017 Hyundai Elite i20 MAGNA 1.2', 'Location': 'Seawoods Navi Mumbai Maharashtra', 'Price': '₹3.93 lakh', 'Fuel': 'Petrol', 'KM driven': '63,814 km', 'Transmission': 'Manual'}
# Option 104: {'Car Model': '2010 Hyundai i20 MAGNA (O) 1.2', 'Location': 'Khar West Mumbai Maharashtra', 'Price': '₹1.33 lakh', 'Fuel': 'Petrol', 'KM driven': '23,516 km', 'Transmission': 'Manual'}
# Option 105: {'Car Model': '2013 Hyundai i10 ERA 1.1', 'Location': 'Khadakpada Kalyan Maharashtra', 'Price': '₹1.58 lakh', 'Fuel': 'Petrol', 'KM driven': '21,266 km', 'Transmission': 'Manual'}
# Option 106: {'Car Model': '2017 Hyundai Xcent E+ 1.2 CRDI', 'Location': 'Ghansoli Navi Mumbai', 'Price': '₹3.21 lakh', 'Fuel': 'Diesel', 'KM driven': '59,600 km', 'Transmission': 'Manual'}
# Option 107: {'Car Model': '2014 Hyundai i20 SPORTZ 1.2', 'Location': 'Thane West Thane Maharashtra', 'Price': '₹2.57 lakh', 'Fuel': 'Petrol', 'KM driven': '68,543 km', 'Transmission': 'Manual'}
# Option 108: {'Car Model': '2014 Hyundai Santro Xing GLS', 'Location': 'Vikhroli Mumbai Maharashtra', 'Price': '₹1.4 lakh', 'Fuel': 'Petrol', 'KM driven': '52,002 km', 'Transmission': 'Manual'}
# Option 109: {'Car Model': '2014 Hyundai Verna FLUIDIC 1.6 VTVT SX AT', 'Location': 'Lower Parel Mumbai', 'Price': '₹3.87 lakh', 'Fuel': 'Petrol', 'KM driven': '52,506 km', 'Transmission': 'Automatic'}
# Option 110: {'Car Model': '2017 Hyundai Grand i10 ASTA 1.2 KAPPA VTVT', 'Location': 'Ghatkopar West Mumbai Maharashtra', 'Price': '₹3.6 lakh', 'Fuel': 'Petrol', 'KM driven': '35,098 km', 'Transmission': 'Manual'}
# Option 111: {'Car Model': '2014 Hyundai Eon SPORTZ', 'Location': 'Mazgaon Mumbai Maharashtra', 'Price': '₹2.1 lakh', 'Fuel': 'Petrol', 'KM driven': '28,226 km', 'Transmission': 'Manual'}
# Option 112: {'Car Model': '2012 Hyundai i10 MAGNA 1.2', 'Location': 'Kalher Bhiwandi Maharashtra', 'Price': '₹1.5 lakh', 'Fuel': 'Petrol', 'KM driven': '56,979 km', 'Transmission': 'Manual'}
# Option 113: {'Car Model': '2012 Hyundai i10 SPORTZ 1.2 AT', 'Location': 'Panvel Navi Mumbai Maharashtra', 'Price': '₹1.95 lakh', 'Fuel': 'Petrol', 'KM driven': '65,211 km', 'Transmission': 'Automatic'}
# Option 114: {'Car Model': '2016 Hyundai Verna FLUIDIC 4S 1.6 VTVT S', 'Location': 'कांदिवली ईस्ट मुंबई', 'Price': '₹4.5 lakh', 'Fuel': 'Petrol', 'KM driven': '43,005 km', 'Transmission': 'Manual'}
# Option 115: {'Car Model': '2011 Hyundai Verna FLUIDIC 1.6 VTVT EX', 'Location': 'Worli Mumbai Maharashtra', 'Price': '₹1.77 lakh', 'Fuel': 'Petrol', 'KM driven': '78,217 km', 'Transmission': 'Manual'}
# Option 116: {'Car Model': '2011 Hyundai i20 MAGNA 1.2', 'Location': 'Shidivinayak Colony Titwala', 'Price': '₹1.35 lakh', 'Fuel': 'Petrol', 'KM driven': '73,468 km', 'Transmission': 'Manual'}
# Option 117: {'Car Model': '2012 Hyundai i20 SPORTZ 1.2', 'Location': 'Mulund West Mumbai Maharashtra', 'Price': '₹1.6 lakh', 'Fuel': 'Petrol', 'KM driven': '90,772 km', 'Transmission': 'Manual'}
# Option 118: {'Car Model': '2015 Hyundai Eon MAGNA +', 'Location': 'Gauripada Kalyan', 'Price': '₹2.49 lakh', 'Fuel': 'Petrol', 'KM driven': '28,494 km', 'Transmission': 'Manual'}
# Option 119: {'Car Model': '2012 Hyundai Verna FLUIDIC 1.6 VTVT EX', 'Location': 'Goregaon West Mumbai Maharashtra', 'Price': '₹2.49 lakh', 'Fuel': 'Petrol', 'KM driven': '7,865 km', 'Transmission': 'Manual'}
# Option 120: {'Car Model': '2011 Hyundai i10 ERA 1.1', 'Location': 'Mira Road East Mira Bhayandar', 'Price': '₹1.14 lakh', 'Fuel': 'Petrol', 'KM driven': '66,957 km', 'Transmission': 'Manual'}
# Option 121: {'Car Model': '2013 Hyundai Verna FLUIDIC VTVT 1.6 EX AT', 'Location': 'कांदिवली पश्चिम मुंबई महाराष्ट्र', 'Price': '₹2.5 lakh', 'Fuel': 'Petrol', 'KM driven': '114,296 km', 'Transmission': 'Automatic'}
# Option 122: {'Car Model': '2018 Hyundai Creta SX PLUS 1.6 PETROL', 'Location': 'Colaba Mumbai Maharashtra', 'Price': '₹6.75 lakh', 'Fuel': 'Petrol', 'KM driven': '75,614 km', 'Transmission': 'Manual'}
# Option 123: {'Car Model': '2011 Hyundai i20 MAGNA (O) 1.2', 'Location': 'Vasai West Sandor Maharashtra', 'Price': '₹1.64 lakh', 'Fuel': 'Petrol', 'KM driven': '61,108 km', 'Transmission': 'Manual'}
# Option 124: {'Car Model': '2012 Hyundai i20 ASTA 1.4 CRDI', 'Location': 'Malad w Mumbai Maharashtra', 'Price': '₹2.52 lakh', 'Fuel': 'Diesel', 'KM driven': '147,214 km', 'Transmission': 'Manual'}
# Option 125: {'Car Model': '2012 Hyundai i10 ASTA 1.2', 'Location': 'Kandivali West Mumbai', 'Price': '₹2.19 lakh', 'Fuel': 'Petrol', 'KM driven': '37,689 km', 'Transmission': 'Manual'}
# Option 126: {'Car Model': '2013 Hyundai Grand i10 MAGNA 1.2 KAPPA VTVT', 'Location': 'Powai Mumbai Maharashtra', 'Price': '₹2.83 lakh', 'Fuel': 'Petrol', 'KM driven': '33,137 km', 'Transmission': 'Manual'}
# Option 127: {'Car Model': '2015 Hyundai Grand i10 ASTA 1.2 KAPPA VTVT', 'Location': 'Kandivali East Mumbai Maharashtra', 'Price': '₹3.27 lakh', 'Fuel': 'Petrol', 'KM driven': '35,790 km', 'Transmission': 'Manual'}
# Option 128: {'Car Model': '2012 Hyundai i20 SPORTZ 1.2', 'Location': 'Dombivli East Nilje Gaon Maharashtra', 'Price': '₹2.31 lakh', 'Fuel': 'Petrol', 'KM driven': '35,703 km', 'Transmission': 'Manual'}
# Option 129: {'Car Model': '2015 Hyundai Elite i20 ASTA 1.4 CRDI', 'Location': 'Sidhi Vinayak Nagar Ulhasnagar', 'Price': '₹4.53 lakh', 'Fuel': 'Diesel', 'KM driven': '74,448 km', 'Transmission': 'Manual'}
# Option 130: {'Car Model': '2014 Hyundai Grand i10 ASTA AT 1.2 KAPPA VTVT', 'Location': 'Bandra West Mumbai', 'Price': '₹2.5 lakh', 'Fuel': 'Petrol', 'KM driven': '55,036 km', 'Transmission': 'Automatic'}
# Option 131: {'Car Model': '2019 Hyundai Elite i20 ASTA 1.4 CRDI (O)', 'Location': 'Bhayandar East Mira Bhayandar Maharashtra', 'Price': '₹5.94 lakh', 'Fuel': 'Diesel', 'KM driven': '93,123 km', 'Transmission': 'Manual'}
# Option 132: {'Car Model': '2012 Hyundai i10 ERA 1.1', 'Location': 'Panvel Navi Mumbai Maharashtra', 'Price': '₹1.9 lakh', 'Fuel': 'Petrol', 'KM driven': '60,000 km', 'Transmission': 'Manual'}
# Option 133: {'Car Model': '2018 Hyundai Verna 1.6 VTVT SX O', 'Location': 'Taloja Navi Mumbai Maharashtra', 'Price': '₹5.8 lakh', 'Fuel': 'Petrol', 'KM driven': '72,478 km', 'Transmission': 'Manual'}
# Option 134: {'Car Model': '2010 Hyundai i20 SPORTZ 1.2', 'Location': 'Dadar Mumbai Maharashtra', 'Price': '₹1.4 lakh', 'Fuel': 'Petrol', 'KM driven': '75,088 km', 'Transmission': 'Manual'}
# Option 135: {'Car Model': '2021 Hyundai NEW I20 SPORTZ 1.2 AT', 'Location': 'Kandivali East Mumbai', 'Price': '₹6.63 lakh', 'Fuel': 'Petrol', 'KM driven': '18,000 km', 'Transmission': 'Automatic'}
# Option 136: {'Car Model': '2016 Hyundai Grand i10 MAGNA 1.2 KAPPA VTVT', 'Location': 'Railway Colony Shahdol', 'Price': '₹2.78 lakh', 'Fuel': 'Petrol', 'KM driven': '76,226 km', 'Transmission': 'Manual'}
# Option 137: {'Car Model': '2012 Hyundai Verna FLUIDIC 1.6 VTVT EX', 'Location': 'Parel Mumbai Maharashtra', 'Price': '₹2.4 lakh', 'Fuel': 'Petrol', 'KM driven': '66,675 km', 'Transmission': 'Manual'}
# Option 138: {'Car Model': '2015 Hyundai Eon MAGNA +', 'Location': 'Mulund East Mumbai Maharashtra', 'Price': '₹2.77 lakh', 'Fuel': 'Petrol', 'KM driven': '52,975 km', 'Transmission': 'Manual'}
# Option 139: {'Car Model': '2013 Hyundai New Elantra 1.8 SX MT VTVT', 'Location': 'Malad East Mumbai Maharashtra', 'Price': '₹3.04 lakh', 'Fuel': 'Petrol', 'KM driven': '155,931 km', 'Transmission': 'Manual'}
# Option 140: {'Car Model': '2012 Hyundai i10 MAGNA 1.1', 'Location': 'Airoli Navi Mumbai Maharashtra', 'Price': '₹2.5 lakh', 'Fuel': 'Petrol', 'KM driven': '17,781 km', 'Transmission': 'Manual'}
# Option 141: {'Car Model': '2016 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Omaxe City 1 Palwal', 'Price': '₹3.09 lakh', 'Fuel': 'Petrol', 'KM driven': '106,846 km', 'Transmission': 'Manual'}
# Option 142: {'Car Model': '2011 Hyundai Accent GLE', 'Location': 'Mira Road East Mira Bhayandar', 'Price': '₹1.21 lakh', 'Fuel': 'Petrol', 'KM driven': '96,078 km', 'Transmission': 'Manual'}
# Option 143: {'Car Model': '2011 Hyundai i20 SPORTZ 1.2', 'Location': 'Goregaon Mumbai Maharashtra', 'Price': '₹1.67 lakh', 'Fuel': 'Petrol', 'KM driven': '69,352 km', 'Transmission': 'Manual'}
# Option 144: {'Car Model': '2015 Hyundai Eon ERA +', 'Location': 'Malad West Mumbai', 'Price': '₹2.3 lakh', 'Fuel': 'Petrol', 'KM driven': '75,901 km', 'Transmission': 'Manual'}
# Option 145: {'Car Model': '2013 Hyundai Verna FLUIDIC 1.6 VTVT SX', 'Location': 'Chembur Mumbai Maharashtra', 'Price': '₹2.93 lakh', 'Fuel': 'Petrol', 'KM driven': '74,000 km', 'Transmission': 'Manual'}
# Option 146: {'Car Model': '2015 Hyundai i10 SPORTZ 1.1', 'Location': 'Airoli Navi Mumbai Maharashtra', 'Price': '₹2.6 lakh', 'Fuel': 'Petrol', 'KM driven': '40,105 km', 'Transmission': 'Manual'}
# Option 147: {'Car Model': '2018 Hyundai NEW SANTRO MAGNA CNG', 'Location': 'Malad West Mumbai', 'Price': '₹3.28 lakh', 'Fuel': 'Petrol', 'KM driven': '70,061 km', 'Transmission': 'Manual'}
# Option 148: {'Car Model': '2011 Hyundai i20 ASTA 1.2', 'Location': 'Dahisar West Mumbai Maharashtra', 'Price': '₹1.79 lakh', 'Fuel': 'Petrol', 'KM driven': '103,332 km', 'Transmission': 'Manual'}
# Option 149: {'Car Model': '2014 Hyundai Eon ERA +', 'Location': 'Kandivali West Mumbai Maharashtra', 'Price': '₹1.93 lakh', 'Fuel': 'Petrol', 'KM driven': '29,197 km', 'Transmission': 'Manual'}
# Option 150: {'Car Model': '2016 Hyundai Elite i20 SPORTZ 1.2', 'Location': 'Vile Parle West Mumbai Maharashtra', 'Price': '₹3.87 lakh', 'Fuel': 'Petrol', 'KM driven': '63,781 km', 'Transmission': 'Manual'}
# Option 151: {'Car Model': '2011 Hyundai i10 MAGNA 1.2', 'Location': 'Kandivali East Mumbai Maharashtra', 'Price': '₹1.08 lakh', 'Fuel': 'Petrol', 'KM driven': '20,311 km', 'Transmission': 'Manual'}
# Option 152: {'Car Model': '2013 Hyundai New Elantra 1.8 SX MT VTVT', 'Location': 'Sanpada Navi Mumbai Maharashtra', 'Price': '₹3.37 lakh', 'Fuel': 'Petrol', 'KM driven': '40,594 km', 'Transmission': 'Manual'}
# Option 153: {'Car Model': '2022 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT CNG', 'Location': 'Malad West Mumbai', 'Price': '₹6.31 lakh', 'Fuel': 'Petrol', 'KM driven': '21,094 km', 'Transmission': 'Manual'}
# Option 154: {'Car Model': '2011 Hyundai i20 SPORTZ 1.2', 'Location': 'Navare Nagar Ambernath', 'Price': '₹1.57 lakh', 'Fuel': 'Petrol', 'KM driven': '99,306 km', 'Transmission': 'Manual'}
# Option 155: {'Car Model': '2010 Hyundai i20 SPORTZ 1.4 CRDI', 'Location': 'Malad East Mumbai', 'Price': '₹2 lakh', 'Fuel': 'Diesel', 'KM driven': '95,383 km', 'Transmission': 'Manual'}
# Option 156: {'Car Model': '2012 Hyundai i20 ASTA 1.2', 'Location': 'Kurla Mumbai Maharashtra', 'Price': '₹2.53 lakh', 'Fuel': 'Petrol', 'KM driven': '62,004 km', 'Transmission': 'Manual'}
# Option 157: {'Car Model': '2011 Hyundai i20 MAGNA 1.2', 'Location': 'Thane East Mumbai', 'Price': '₹1.36 lakh', 'Fuel': 'Petrol', 'KM driven': '68,216 km', 'Transmission': 'Manual'}
# Option 158: {'Car Model': '2011 Hyundai i10 SPORTZ 1.2', 'Location': 'Colaba Mumbai Maharashtra', 'Price': '₹1.71 lakh', 'Fuel': 'Petrol', 'KM driven': '30,883 km', 'Transmission': 'Manual'}
# Option 159: {'Car Model': '2019 Hyundai Grand i10 MAGNA 1.2 KAPPA VTVT', 'Location': 'Malad West Mumbai', 'Price': '₹3.95 lakh', 'Fuel': 'Petrol', 'KM driven': '20,583 km', 'Transmission': 'Manual'}
# Option 160: {'Car Model': '2015 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Dahisar East Mumbai Maharashtra', 'Price': '₹3.24 lakh', 'Fuel': 'Petrol', 'KM driven': '40,250 km', 'Transmission': 'Manual'}
# Option 161: {'Car Model': '2011 Hyundai Verna FLUIDIC 1.6 CRDI SX', 'Location': 'Kopar Khairane Navi Mumbai', 'Price': '₹2.31 lakh', 'Fuel': 'Diesel', 'KM driven': '143,192 km', 'Transmission': 'Manual'}
# Option 162: {'Car Model': '2017 Hyundai Elite i20 SPORTZ 1.2', 'Location': 'Karanjade Navi Mumbai Maharashtra', 'Price': '₹4.5 lakh', 'Fuel': 'Petrol', 'KM driven': '58,969 km', 'Transmission': 'Manual'}
# Option 163: {'Car Model': '2024 Hyundai AURA S 1.2 CNG', 'Location': 'Thane West Thane Maharashtra', 'Price': '₹7.17 lakh', 'Fuel': 'Petrol', 'KM driven': '20,006 km', 'Transmission': 'Manual'}
# Option 164: {'Car Model': '2015 Hyundai Verna FLUIDIC 1.6 CRDI SX AT', 'Location': 'Thane West Thane', 'Price': '₹3.88 lakh', 'Fuel': 'Diesel', 'KM driven': '233,237 km', 'Transmission': 'Automatic'}
# Option 165: {'Car Model': '2013 Hyundai Verna FLUIDIC 1.6 VTVT EX', 'Location': 'Kansai Section Ambernath Maharashtra', 'Price': '₹3.38 lakh', 'Fuel': 'Petrol', 'KM driven': '90,691 km', 'Transmission': 'Manual'}
# Option 166: {'Car Model': '2010 Hyundai i20 ASTA 1.2', 'Location': 'Panvel Navi Mumbai Maharashtra', 'Price': '₹0.92 lakh', 'Fuel': 'Petrol', 'KM driven': '103,579 km', 'Transmission': 'Manual'}
# Option 167: {'Car Model': '2012 Hyundai i10 MAGNA 1.1', 'Location': 'Virar West Virar Maharashtra', 'Price': '₹1.39 lakh', 'Fuel': 'Petrol', 'KM driven': '41,397 km', 'Transmission': 'Manual'}
# Option 168: {'Car Model': '2013 Hyundai i20 MAGNA 1.2', 'Location': 'Nerul Navi Mumbai', 'Price': '₹2.87 lakh', 'Fuel': 'Petrol', 'KM driven': '33,180 km', 'Transmission': 'Manual'}
# Option 169: {'Car Model': '2011 Hyundai i10 SPORTZ 1.2', 'Location': 'Kharghar Navi Mumbai Maharashtra', 'Price': '₹1.62 lakh', 'Fuel': 'Petrol', 'KM driven': '46,169 km', 'Transmission': 'Manual'}
# Option 170: {'Car Model': '2017 Hyundai Grand i10 SPORTZ (O) AT 1.2 KAPPA VTVT', 'Location': 'Avachit Pada Bhiwandi', 'Price': '₹3.49 lakh', 'Fuel': 'Petrol', 'KM driven': '160,981 km', 'Transmission': 'Automatic'}
# Option 171: {'Car Model': '2015 Hyundai Xcent SX 1.2 (O)', 'Location': 'Badlapur Thane Maharashtra', 'Price': '₹3.62 lakh', 'Fuel': 'Petrol', 'KM driven': '71,071 km', 'Transmission': 'Manual'}
# Option 172: {'Car Model': '2012 Hyundai Santro Xing GL PLUS (CNG)', 'Location': 'Gandhi Nagar Muzaffarnagar', 'Price': '₹1.23 lakh', 'Fuel': 'Petrol', 'KM driven': '86,858 km', 'Transmission': 'Manual'}
# Option 173: {'Car Model': '2010 Hyundai i10 SPORTZ 1.2', 'Location': 'Bhagwati Colony Saharanpur', 'Price': '₹0.89 lakh', 'Fuel': 'Petrol', 'KM driven': '86,660 km', 'Transmission': 'Manual'}
# Option 174: {'Car Model': '2013 Hyundai Verna FLUIDIC 1.6 EX CRDI AT', 'Location': 'Panvel Navi Mumbai', 'Price': '₹3.47 lakh', 'Fuel': 'Diesel', 'KM driven': '110,248 km', 'Transmission': 'Automatic'}
# Option 175: {'Car Model': '2015 Hyundai Xcent SX 1.2', 'Location': 'Khadakpada Kalyan Maharashtra', 'Price': '₹3.61 lakh', 'Fuel': 'Petrol', 'KM driven': '36,033 km', 'Transmission': 'Manual'}
# Option 176: {'Car Model': '2014 Hyundai Elite i20 ASTA 1.4 CRDI', 'Location': 'Ahore Ahore', 'Price': '₹3.6 lakh', 'Fuel': 'Diesel', 'KM driven': '84,506 km', 'Transmission': 'Manual'}
# Option 177: {'Car Model': '2016 Hyundai Xcent SX 1.2', 'Location': 'X2XQ+JH Navi Mumbai Maharashtra', 'Price': '₹3.7 lakh', 'Fuel': 'Petrol', 'KM driven': '106,017 km', 'Transmission': 'Manual'}
# Option 178: {'Car Model': '2015 Hyundai Grand i10 ASTA (O) 1.2 KAPPA VTVT', 'Location': 'Lower Parel Mumbai', 'Price': '₹2.9 lakh', 'Fuel': 'Petrol', 'KM driven': '79,754 km', 'Transmission': 'Manual'}
# Option 179: {'Car Model': '2011 Hyundai i10 SPORTZ 1.2', 'Location': 'Thane West Thane Maharashtra', 'Price': '₹1.56 lakh', 'Fuel': 'Petrol', 'KM driven': '44,366 km', 'Transmission': 'Manual'}
# Option 180: {'Car Model': '2014 Hyundai i20 MAGNA (O) 1.2', 'Location': 'Kandivali West Mumbai', 'Price': '₹2.7 lakh', 'Fuel': 'Petrol', 'KM driven': '31,720 km', 'Transmission': 'Manual'}
# Option 181: {'Car Model': '2013 Hyundai i20 SPORTZ 1.2', 'Location': 'T-5 Mumbai Maharashtra', 'Price': '₹2.38 lakh', 'Fuel': 'Petrol', 'KM driven': '107,051 km', 'Transmission': 'Manual'}
# Option 182: {'Car Model': '2023 Hyundai Verna 1.5 TURBO GDI MT SX', 'Location': 'Sandor Vasai-Virar Maharashtra', 'Price': '₹12 lakh', 'Fuel': 'Petrol', 'KM driven': '18,300 km', 'Transmission': 'Manual'}
# Option 183: {'Car Model': '2011 Hyundai Verna FLUIDIC 1.6 VTVT SX', 'Location': 'Dahisar East Mumbai Maharashtra', 'Price': '₹2 lakh', 'Fuel': 'Petrol', 'KM driven': '87,000 km', 'Transmission': 'Manual'}
# Option 184: {'Car Model': '2017 Hyundai Grand i10 SPORTZ (O) AT 1.2 KAPPA VTVT', 'Location': 'Sudhir Tower Mulund West Mumbai', 'Price': '₹4.76 lakh', 'Fuel': 'Petrol', 'KM driven': '66,321 km', 'Transmission': 'Automatic'}
# Option 185: {'Car Model': '2013 Hyundai i20 ASTA 1.2', 'Location': 'Chinchpada Gaon Kalyan Maharashtra', 'Price': '₹2.93 lakh', 'Fuel': 'Petrol', 'KM driven': '51,005 km', 'Transmission': 'Manual'}
# Option 186: {'Car Model': '2020 Hyundai VENUE SX PLUS 1.0 TURBO DCT', 'Location': 'Kalwa Thane Maharashtra', 'Price': '₹7.59 lakh', 'Fuel': 'Petrol', 'KM driven': '36,438 km', 'Transmission': 'Automatic'}
# Option 187: {'Car Model': '2016 Hyundai Creta SX PLUS AT 1.6 DIESEL', 'Location': 'Ghatkopar East Mumbai Maharashtra', 'Price': '₹8.23 lakh', 'Fuel': 'Diesel', 'KM driven': '153,845 km', 'Transmission': 'Automatic'}
# Option 188: {'Car Model': '2014 Hyundai Xcent S 1.2', 'Location': 'Thane West Thane', 'Price': '₹3.27 lakh', 'Fuel': 'Petrol', 'KM driven': '44,015 km', 'Transmission': 'Manual'}
# Option 189: {'Car Model': '2014 Hyundai Xcent S 1.1 CRDI', 'Location': 'Kanjurmarg East Mumbai Maharashtra', 'Price': '₹3.28 lakh', 'Fuel': 'Diesel', 'KM driven': '61,481 km', 'Transmission': 'Manual'}
# Option 190: {'Car Model': '2018 Hyundai Grand i10 MAGNA 1.2 KAPPA VTVT', 'Location': 'Kailash Colony Ulhasnagar', 'Price': '₹3.43 lakh', 'Fuel': 'Petrol', 'KM driven': '103,917 km', 'Transmission': 'Manual'}
# Option 191: {'Car Model': '2017 Hyundai Creta SX PLUS 1.6 PETROL', 'Location': 'Lok Dhara Kalyan', 'Price': '₹7.87 lakh', 'Fuel': 'Petrol', 'KM driven': '59,225 km', 'Transmission': 'Manual'}
# Option 192: {'Car Model': '2015 Hyundai Verna 1.6 CRDI SX', 'Location': 'Nerul Navi Mumbai', 'Price': '₹5.12 lakh', 'Fuel': 'Diesel', 'KM driven': '95,613 km', 'Transmission': 'Manual'}
# Option 193: {'Car Model': '2018 Hyundai Xcent E+', 'Location': 'Sector 38 Gurugram', 'Price': '₹3.99 lakh', 'Fuel': 'Petrol', 'KM driven': '56,613 km', 'Transmission': 'Manual'}
# Option 194: {'Car Model': '2018 Hyundai Verna 1.6 VTVT SX (O) AT', 'Location': 'Borivali Mumbai Maharashtra', 'Price': '₹7.25 lakh', 'Fuel': 'Petrol', 'KM driven': '49,497 km', 'Transmission': 'Automatic'}
# Option 195: {'Car Model': '2014 Hyundai Xcent S 1.2', 'Location': 'Panvel Navi Mumbai Maharashtra', 'Price': '₹3.5 lakh', 'Fuel': 'Petrol', 'KM driven': '95,267 km', 'Transmission': 'Manual'}
# Option 196: {'Car Model': '2015 Hyundai Elite i20 SPORTZ 1.2', 'Location': 'Mulund West Mumbai Maharashtra', 'Price': '₹3.9 lakh', 'Fuel': 'Petrol', 'KM driven': '53,353 km', 'Transmission': 'Manual'}
# Option 197: {'Car Model': '2015 Hyundai Xcent S (O) 1.2', 'Location': 'Panvel Navi Mumbai Maharashtra', 'Price': '₹3.37 lakh', 'Fuel': 'Petrol', 'KM driven': '75,162 km', 'Transmission': 'Manual'}
# Option 198: {'Car Model': '2015 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Powai Mumbai Maharashtra', 'Price': '₹3.75 lakh', 'Fuel': 'Petrol', 'KM driven': '51,551 km', 'Transmission': 'Manual'}
# Option 199: {'Car Model': '2011 Hyundai i10 SPORTZ 1.2 AT', 'Location': 'Kandivali East Mumbai', 'Price': '₹1.29 lakh', 'Fuel': 'Petrol', 'KM driven': '70,834 km', 'Transmission': 'Automatic'}
# Option 200: {'Car Model': '2014 Hyundai Xcent S 1.2', 'Location': 'Thane West Thane', 'Price': '₹3.17 lakh', 'Fuel': 'Petrol', 'KM driven': '122,129 km', 'Transmission': 'Manual'}
# Option 201: {'Car Model': '2024 Hyundai EXTER SX(O) CONNECT 1.2 AMT DUAL TONE', 'Location': 'Thane West Thane Maharashtra', 'Price': '₹8.87 lakh', 'Fuel': 'Petrol', 'KM driven': '6,639 km', 'Transmission': 'Automatic'}
# Option 202: {'Car Model': '2017 Hyundai Creta SX PLUS AT 1.6 PETROL', 'Location': 'Mazgaon Mumbai Maharashtra', 'Price': '₹8.25 lakh', 'Fuel': 'Petrol', 'KM driven': '28,506 km', 'Transmission': 'Automatic'}
# Option 203: {'Car Model': '2015 Hyundai Elite i20 SPORTZ 1.2', 'Location': 'Bandra West Mumbai Maharashtra', 'Price': '₹3.99 lakh', 'Fuel': 'Petrol', 'KM driven': '10,456 km', 'Transmission': 'Manual'}
# Option 204: {'Car Model': '2024 Hyundai Creta N Line N8 1.5 Turbo MT', 'Location': 'Mulund West Mumbai Maharashtra', 'Price': '₹16 lakh', 'Fuel': 'Petrol', 'KM driven': '7,506 km', 'Transmission': 'Manual'}
# Option 205: {'Car Model': '2015 Hyundai Xcent S (O) 1.2', 'Location': 'Gokul Nagar Bhiwandi Maharashtra', 'Price': '₹3.12 lakh', 'Fuel': 'Petrol', 'KM driven': '71,115 km', 'Transmission': 'Manual'}
# Option 206: {'Car Model': '2015 Hyundai i20 Active 1.2 S', 'Location': 'Kandivali East Mumbai', 'Price': '₹5.43 lakh', 'Fuel': 'Petrol', 'KM driven': '39,665 km', 'Transmission': 'Manual'}
# Option 207: {'Car Model': '2023 Hyundai Creta SX (O) IVT 1.5 PETROL', 'Location': 'Mira Road East Mira Bhayandar Maharashtra', 'Price': '₹16.95 lakh', 'Fuel': 'Petrol', 'KM driven': '20,378 km', 'Transmission': 'Automatic'}
# Option 208: {'Car Model': '2015 Hyundai Xcent S (O) 1.2', 'Location': 'ठाणे वेस्ट ठाणे', 'Price': '₹3 lakh', 'Fuel': 'Petrol', 'KM driven': '103,807 km', 'Transmission': 'Manual'}
# Option 209: {'Car Model': '2015 Hyundai Xcent SX AT 1.2 (O)', 'Location': 'Thane West Thane Maharashtra', 'Price': '₹3.6 lakh', 'Fuel': 'Petrol', 'KM driven': '74,262 km', 'Transmission': 'Automatic'}
# Option 210: {'Car Model': '2010 Hyundai i10 ASTA 1.2 AT SUNROOF', 'Location': 'Andheri East Mumbai', 'Price': '₹1.67 lakh', 'Fuel': 'Petrol', 'KM driven': '63,017 km', 'Transmission': 'Automatic'}
# Option 211: {'Car Model': '2017 Hyundai Elite i20 ASTA 1.2 DUAL TONE', 'Location': 'Dombivli East Mumbai Maharashtra', 'Price': '₹4.65 lakh', 'Fuel': 'Petrol', 'KM driven': '58,002 km', 'Transmission': 'Manual'}
# Option 212: {'Car Model': '2016 Hyundai Xcent S 1.2', 'Location': 'Kandivali East Mumbai', 'Price': '₹3.49 lakh', 'Fuel': 'Petrol', 'KM driven': '48,196 km', 'Transmission': 'Manual'}
# Option 213: {'Car Model': '2013 Hyundai Verna FLUIDIC 1.6 CRDI SX OPT AT', 'Location': 'Andheri West Mumbai', 'Price': '₹3.65 lakh', 'Fuel': 'Diesel', 'KM driven': '167,081 km', 'Transmission': 'Automatic'}
# Option 214: {'Car Model': '2021 Hyundai Creta SX (O) IVT 1.5 PETROL', 'Location': 'Sewri Mumbai Maharashtra', 'Price': '₹15.29 lakh', 'Fuel': 'Petrol', 'KM driven': '60,819 km', 'Transmission': 'Automatic'}
# Option 215: {'Car Model': '2016 Hyundai Verna 1.6 VTVT SX AT', 'Location': 'Chembur Mumbai Maharashtra', 'Price': '₹6.42 lakh', 'Fuel': 'Petrol', 'KM driven': '61,655 km', 'Transmission': 'Automatic'}
# Option 216: {'Car Model': '2023 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT CNG', 'Location': 'Mira Road East Mira Bhayandar Maharashtra', 'Price': '₹6.94 lakh', 'Fuel': 'Petrol', 'KM driven': '67,420 km', 'Transmission': 'Manual'}
# Option 217: {'Car Model': '2010 Hyundai i20 MAGNA 1.2', 'Location': 'Kurar Village Mumbai', 'Price': '₹1.36 lakh', 'Fuel': 'Petrol', 'KM driven': '48,829 km', 'Transmission': 'Manual'}
# Option 218: {'Car Model': '2016 Hyundai Grand i10 ASTA (O) AT 1.2 KAPPA VTVT', 'Location': 'Sector 58A Seawoods Navi Mumbai', 'Price': '₹3.5 lakh', 'Fuel': 'Petrol', 'KM driven': '104,376 km', 'Transmission': 'Automatic'}
# Option 219: {'Car Model': '2019 Hyundai VENUE SX PLUS 1.0 TURBO DCT', 'Location': 'Thane West Thane', 'Price': '₹8.22 lakh', 'Fuel': 'Petrol', 'KM driven': '11,275 km', 'Transmission': 'Automatic'}
# Option 220: {'Car Model': '2021 Hyundai NEW SANTRO SPORTZ CNG', 'Location': 'Kandivali East Mumbai Maharashtra', 'Price': '₹4 lakh', 'Fuel': 'Petrol', 'KM driven': '51,219 km', 'Transmission': 'Manual'}
# Option 221: {'Car Model': '2022 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT CNG', 'Location': 'Shahad Ulhasnagar Maharashtra', 'Price': '₹6.11 lakh', 'Fuel': 'Petrol', 'KM driven': '33,363 km', 'Transmission': 'Manual'}
# Option 222: {'Car Model': '2021 Hyundai VENUE SX 1.0 TURBO IMT DUAL TONE SPORT', 'Location': 'Kalwa Thane Maharashtra', 'Price': '₹6.45 lakh', 'Fuel': 'Petrol', 'KM driven': '52,122 km', 'Transmission': 'Manual'}
# Option 223: {'Car Model': '2017 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'Sion Mumbai Maharashtra', 'Price': '₹3.71 lakh', 'Fuel': 'Petrol', 'KM driven': '19,807 km', 'Transmission': 'Manual'}
# Option 224: {'Car Model': '2017 Hyundai Grand i10 SPORTZ (O) AT 1.2 KAPPA VTVT', 'Location': 'Chembur Mumbai', 'Price': '₹4.09 lakh', 'Fuel': 'Petrol', 'KM driven': '28,684 km', 'Transmission': 'Automatic'}
# Option 225: {'Car Model': '2013 Hyundai i20 SPORTZ 1.2', 'Location': 'Thane West Thane Maharashtra', 'Price': '₹3.27 lakh', 'Fuel': 'Petrol', 'KM driven': '30,389 km', 'Transmission': 'Manual'}
# Option 226: {'Car Model': '2021 Hyundai Creta EX 1.5 DIESEL', 'Location': 'Nalasopara West Nala Sopara Maharashtra', 'Price': '₹11.4 lakh', 'Fuel': 'Diesel', 'KM driven': '90,245 km', 'Transmission': 'Manual'}
# Option 227: {'Car Model': '2024 Hyundai AURA S 1.2 CNG', 'Location': 'Dombivli East Dombivli Maharashtra', 'Price': '₹7.91 lakh', 'Fuel': 'Petrol', 'KM driven': '8,577 km', 'Transmission': 'Manual'}
# Option 228: {'Car Model': '2015 Hyundai Xcent S 1.1 CRDI', 'Location': 'Ulhasnagar Kalyan Maharashtra', 'Price': '₹3.64 lakh', 'Fuel': 'Diesel', 'KM driven': '82,714 km', 'Transmission': 'Manual'}
# Option 229: {'Car Model': '2010 Hyundai Verna TRANSFORM 1.5 SX CRDI', 'Location': 'Narpoli Bhiwandi Maharashtra', 'Price': '₹1.19 lakh', 'Fuel': 'Diesel', 'KM driven': '97,862 km', 'Transmission': 'Manual'}
# Option 230: {'Car Model': '2023 Hyundai NEW I20 ASTA (O) 1.0 TURBO GDI DCT', 'Location': 'Powai Mumbai', 'Price': '₹8 lakh', 'Fuel': 'Petrol', 'KM driven': '12,782 km', 'Transmission': 'Automatic'}
# Option 231: {'Car Model': '2016 Hyundai Creta SX 1.6 Petrol', 'Location': 'Shirgaon Badlapur Maharashtra', 'Price': '₹6.22 lakh', 'Fuel': 'Petrol', 'KM driven': '68,190 km', 'Transmission': 'Manual'}
# Option 232: {'Car Model': '2016 Hyundai Creta SX PLUS 1.6 PETROL', 'Location': 'Malabar Hill Mumbai', 'Price': '₹6.45 lakh', 'Fuel': 'Petrol', 'KM driven': '82,568 km', 'Transmission': 'Manual'}
# Option 233: {'Car Model': '2013 Hyundai Grand i10 SPORTZ 1.2 KAPPA VTVT', 'Location': 'कांदिवली पश्चिम मुंबई महाराष्ट्र', 'Price': '₹3.15 lakh', 'Fuel': 'Petrol', 'KM driven': '21,477 km', 'Transmission': 'Manual'}
# Option 234: {'Car Model': '2016 Hyundai Creta SX PLUS AT 1.6 PETROL', 'Location': 'Vile Parle West Mumbai Maharashtra', 'Price': '₹8.79 lakh', 'Fuel': 'Petrol', 'KM driven': '41,432 km', 'Transmission': 'Automatic'}
# Option 235: {'Car Model': '2012 Hyundai i20 ASTA 1.4 AT', 'Location': 'Powai Mumbai Maharashtra', 'Price': '₹2.69 lakh', 'Fuel': 'Petrol', 'KM driven': '40,431 km', 'Transmission': 'Automatic'}
# Option 236: {'Car Model': '2019 Hyundai NEW SANTRO SPORTZ AMT', 'Location': 'Andheri East Mumbai', 'Price': '₹3.79 lakh', 'Fuel': 'Petrol', 'KM driven': '63,784 km', 'Transmission': 'Automatic'}
# Option 237: {'Car Model': '2019 Hyundai New Elantra 2.0 S PETROL', 'Location': 'Mazgaon Mumbai', 'Price': '₹7.75 lakh', 'Fuel': 'Petrol', 'KM driven': '82,706 km', 'Transmission': 'Manual'}
# Option 238: {'Car Model': '2014 Hyundai Grand i10 ASTA AT 1.2 KAPPA VTVT', 'Location': 'Kopar Khairane Navi Mumbai Maharashtra', 'Price': '₹3.4 lakh', 'Fuel': 'Petrol', 'KM driven': '41,051 km', 'Transmission': 'Automatic'}
# Option 239: {'Car Model': '2022 Hyundai VENUE SX 1.5 CRDI', 'Location': 'Dombivli East Dombivli', 'Price': '₹9.68 lakh', 'Fuel': 'Diesel', 'KM driven': '67,903 km', 'Transmission': 'Manual'}
# Option 240: {'Car Model': '2024 Hyundai AURA SX 1.2 CNG', 'Location': 'Navi Mumbai Mhatwali Maharashtra', 'Price': '₹8.1 lakh', 'Fuel': 'Petrol', 'KM driven': '27,004 km', 'Transmission': 'Manual'}
# Option 241: {'Car Model': '2016 Hyundai Elite i20 ASTA 1.2 (O)', 'Location': 'Malad East Mumbai Maharashtra', 'Price': '₹4.1 lakh', 'Fuel': 'Petrol', 'KM driven': '62,148 km', 'Transmission': 'Manual'}
# Option 242: {'Car Model': '2010 Hyundai i10 SPORTZ 1.2', 'Location': 'Gaurav City Mira Bhayandar', 'Price': '₹1.02 lakh', 'Fuel': 'Petrol', 'KM driven': '102,018 km', 'Transmission': 'Manual'}
# Option 243: {'Car Model': '2014 Hyundai Verna FLUIDIC 1.6 CRDI SX AT', 'Location': 'Khadakpada Kalyan', 'Price': '₹3.9 lakh', 'Fuel': 'Diesel', 'KM driven': '78,849 km', 'Transmission': 'Automatic'}
# Option 244: {'Car Model': '2021 Hyundai NEW SANTRO SPORTZ CNG', 'Location': 'Dahisar East Mumbai Maharashtra', 'Price': '₹5.65 lakh', 'Fuel': 'Petrol', 'KM driven': '17,390 km', 'Transmission': 'Manual'}
# Option 245: {'Car Model': '2018 Hyundai New Elantra 2.0 SX AT PETROL', 'Location': 'Worli Mumbai', 'Price': '₹8.06 lakh', 'Fuel': 'Petrol', 'KM driven': '45,922 km', 'Transmission': 'Automatic'}
# Option 246: {'Car Model': '2016 Hyundai Creta S 1.4 DIESEL', 'Location': 'Jogeshwari West Mumbai', 'Price': '₹6.3 lakh', 'Fuel': 'Diesel', 'KM driven': '101,174 km', 'Transmission': 'Manual'}
# Option 247: {'Car Model': '2015 Hyundai Creta S 1.6 PETROL', 'Location': 'Malad East Mumbai Maharashtra', 'Price': '₹5.75 lakh', 'Fuel': 'Petrol', 'KM driven': '88,479 km', 'Transmission': 'Manual'}
# Option 248: {'Car Model': '2014 Hyundai Santa Fe 4 WD AT', 'Location': 'Dombivli West Dombivli', 'Price': '₹4.99 lakh', 'Fuel': 'Diesel', 'KM driven': '132,676 km', 'Transmission': 'Automatic'}
# Option 249: {'Car Model': '2017 Hyundai Grand i10 SPORTZ (O) AT 1.2 KAPPA VTVT', 'Location': 'Andheri West Mumbai Maharashtra', 'Price': '₹4.86 lakh', 'Fuel': 'Petrol', 'KM driven': '39,882 km', 'Transmission': 'Automatic'}
# Option 250: {'Car Model': '2012 Hyundai New Elantra 1.6 CRDI', 'Location': 'Virar East Virar Maharashtra', 'Price': '₹3.73 lakh', 'Fuel': 'Diesel', 'KM driven': '100,146 km', 'Transmission': 'Manual'}
# Option 251: {'Car Model': '2020 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT', 'Location': 'Virar West Virar Maharashtra', 'Price': '₹4.5 lakh', 'Fuel': 'Petrol', 'KM driven': '43,769 km', 'Transmission': 'Manual'}
# Option 252: {'Car Model': '2019 Hyundai VENUE SX (O) 1.5 CRDI', 'Location': 'Kharghar Navi Mumbai Maharashtra', 'Price': '₹7.8 lakh', 'Fuel': 'Diesel', 'KM driven': '65,776 km', 'Transmission': 'Manual'}
# Option 253: {'Car Model': '2017 Hyundai Verna 1.6 VTVT SX AT', 'Location': 'Santacruz East Mumbai Maharashtra', 'Price': '₹6.27 lakh', 'Fuel': 'Petrol', 'KM driven': '39,824 km', 'Transmission': 'Automatic'}
# Option 254: {'Car Model': '2023 Hyundai Verna 1.5 TURBO GDI MT SX', 'Location': 'Sandor Vasai-Virar Maharashtra', 'Price': '₹11.5 lakh', 'Fuel': 'Petrol', 'KM driven': '18,153 km', 'Transmission': 'Manual'}
# Option 255: {'Car Model': '2018 Hyundai NEW SANTRO MAGNA CNG', 'Location': 'Panvel Navi Mumbai', 'Price': '₹3.53 lakh', 'Fuel': 'Petrol', 'KM driven': '66,367 km', 'Transmission': 'Manual'}
# Option 256: {'Car Model': '2015 Hyundai Creta SX PLUS 1.6 PETROL', 'Location': 'Kandivali West Mumbai', 'Price': '₹6.54 lakh', 'Fuel': 'Petrol', 'KM driven': '52,310 km', 'Transmission': 'Manual'}
# Option 257: {'Car Model': '2023 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT CNG', 'Location': 'Taloja Navi Mumbai', 'Price': '₹6.2 lakh', 'Fuel': 'Petrol', 'KM driven': '40,728 km', 'Transmission': 'Manual'}
# Option 258: {'Car Model': '2022 Hyundai VENUE S (O) 1.0 TURBO IMT', 'Location': 'Patel Nagar New Delhi', 'Price': '₹8.6 lakh', 'Fuel': 'Petrol', 'KM driven': '3,678 km', 'Transmission': 'Manual'}
# Option 259: {'Car Model': '2015 Hyundai Creta SX PLUS 1.6 DIESEL', 'Location': 'Bholenath nagar 523J+8X Thane Maharashtra', 'Price': '₹7.25 lakh', 'Fuel': 'Diesel', 'KM driven': '102,468 km', 'Transmission': 'Manual'}
# Option 260: {'Car Model': '2018 Hyundai Creta S 1.4 DIESEL', 'Location': 'Thane West Thane', 'Price': '₹8.5 lakh', 'Fuel': 'Diesel', 'KM driven': '48,125 km', 'Transmission': 'Manual'}
# Option 261: {'Car Model': '2021 Hyundai VENUE SX PLUS 1.0 TURBO DCT', 'Location': 'Mumbai Thane Maharashtra', 'Price': '₹8.46 lakh', 'Fuel': 'Petrol', 'KM driven': '46,976 km', 'Transmission': 'Automatic'}
# Option 262: {'Car Model': '2017 Hyundai Xcent BASE 1.1', 'Location': 'Khadakpada Kalyan Maharashtra', 'Price': '₹3.52 lakh', 'Fuel': 'Diesel', 'KM driven': '156,113 km', 'Transmission': 'Manual'}
# Option 263: {'Car Model': '2015 Hyundai Creta SX 1.6 DIESEL', 'Location': 'Borivali Mumbai Maharashtra', 'Price': '₹7.09 lakh', 'Fuel': 'Diesel', 'KM driven': '112,000 km', 'Transmission': 'Manual'}
# Option 264: {'Car Model': '2019 Hyundai Creta SX AT 1.6 PETROL', 'Location': 'Kharghar Navi Mumbai Maharashtra', 'Price': '₹9.5 lakh', 'Fuel': 'Petrol', 'KM driven': '114,066 km', 'Transmission': 'Automatic'}
# Option 265: {'Car Model': '2020 Hyundai VENUE SX 1.0 (O) TURBO', 'Location': 'Navi Mumbai Shilottar Raichur Maharashtra', 'Price': '₹7 lakh', 'Fuel': 'Petrol', 'KM driven': '44,614 km', 'Transmission': 'Manual'}
# Option 266: {'Car Model': '2016 Hyundai i20 Active 1.2 S', 'Location': 'Mumbai Andheri Maharashtra', 'Price': '₹4.25 lakh', 'Fuel': 'Petrol', 'KM driven': '73,702 km', 'Transmission': 'Manual'}
# Option 267: {'Car Model': '2021 Hyundai ALCAZAR 1.5 SIGNATURE (O) AT 6STR', 'Location': 'Mulund East Mumbai Maharashtra', 'Price': '₹16.62 lakh', 'Fuel': 'Diesel', 'KM driven': '37,328 km', 'Transmission': 'Automatic'}
# Option 268: {'Car Model': '2019 Hyundai Creta SX AT 1.6 PETROL', 'Location': 'Kandivali West Mumbai', 'Price': '₹9.4 lakh', 'Fuel': 'Petrol', 'KM driven': '83,474 km', 'Transmission': 'Automatic'}
# Option 269: {'Car Model': '2022 Hyundai Creta S PLUS 1.4 TURBO DCT', 'Location': 'Santacruz East Mumbai Maharashtra', 'Price': '₹14.68 lakh', 'Fuel': 'Petrol', 'KM driven': '34,423 km', 'Transmission': 'Automatic'}
# Option 270: {'Car Model': '2023 Hyundai Verna SX 1.5 l MPI', 'Location': 'Thane West Thane Maharashtra', 'Price': '₹10.75 lakh', 'Fuel': 'Petrol', 'KM driven': '18,038 km', 'Transmission': 'Manual'}
# Option 271: {'Car Model': '2019 Hyundai Creta SX AT 1.6 PETROL', 'Location': 'Wadala East Mumbai Maharashtra', 'Price': '₹8.85 lakh', 'Fuel': 'Petrol', 'KM driven': '46,486 km', 'Transmission': 'Automatic'}
# Option 272: {'Car Model': '2022 Hyundai Creta SX (O) AT 1.5 DIESEL', 'Location': 'CBD Belapur Navi Mumbai Maharashtra', 'Price': '₹16.95 lakh', 'Fuel': 'Diesel', 'KM driven': '41,826 km', 'Transmission': 'Automatic'}
# Option 273: {'Car Model': '2019 Hyundai XCENT PRIME T VTVT PLUS CNG', 'Location': 'Ulwe Navi Mumbai Maharashtra', 'Price': '₹3.96 lakh', 'Fuel': 'Petrol', 'KM driven': '160,068 km', 'Transmission': 'Manual'}
# Option 274: {'Car Model': '2023 Hyundai Verna SX (O) 1.5 VTVT IVT', 'Location': 'Zone 3 Mumbai Suburban Maharashtra', 'Price': '₹16 lakh', 'Fuel': 'Petrol', 'KM driven': '9,071 km', 'Transmission': 'Automatic'}
# Option 275: {'Car Model': '2021 Hyundai NEW I20 SPORTZ 1.2 AT', 'Location': 'Sandor Vasai-Virar Maharashtra', 'Price': '₹7.19 lakh', 'Fuel': 'Petrol', 'KM driven': '19,909 km', 'Transmission': 'Automatic'}
# Option 276: {'Car Model': '2020 Hyundai GRAND I10 NIOS SPORTZ 1.2 KAPPA VTVT CNG', 'Location': 'Panvel Navi Mumbai Maharashtra', 'Price': '₹5.76 lakh', 'Fuel': 'Petrol', 'KM driven': '25,865 km', 'Transmission': 'Manual'}
# Option 277: {'Car Model': '2019 Hyundai VENUE SX (O) 1.5 CRDI', 'Location': 'SH54 Navi Mumbai Maharashtra', 'Price': '₹8.96 lakh', 'Fuel': 'Diesel', 'KM driven': '103,970 km', 'Transmission': 'Manual'}
# Option 278: {'Car Model': '2020 Hyundai Grand i10 MAGNA 1.2 KAPPA VTVT', 'Location': 'Thane West Thane Maharashtra', 'Price': '₹4.36 lakh', 'Fuel': 'Petrol', 'KM driven': '23,715 km', 'Transmission': 'Manual'}
# Option 279: {'Car Model': '2024 Hyundai EXTER SX 1.2 CNG MT', 'Location': 'CBD Belapur Navi Mumbai Maharashtra', 'Price': '₹8.01 lakh', 'Fuel': 'Petrol', 'KM driven': '6,503 km', 'Transmission': 'Manual'}
# Option 280: {'Car Model': '2022 Hyundai NEW I20 ASTA (O) 1.0 TURBO GDI DCT', 'Location': 'Sector 18 Gurugram', 'Price': '₹8.73 lakh', 'Fuel': 'Petrol', 'KM driven': '51,637 km', 'Transmission': 'Automatic'}
# Option 281: {'Car Model': '2023 Hyundai Verna SX(O) 1.5 MPI IVT', 'Location': 'Ulwe Navi Mumbai Maharashtra', 'Price': '₹14.5 lakh', 'Fuel': 'Petrol', 'KM driven': '3,115 km', 'Transmission': 'Automatic'}
# Option 282: {'Car Model': '2017 Hyundai Creta SX PLUS 1.6 PETROL', 'Location': 'Anjur Sarang', 'Price': '₹7 lakh', 'Fuel': 'Petrol', 'KM driven': '40,563 km', 'Transmission': 'Manual'}
# Option 283: {'Car Model': '2014 Hyundai i20 ASTA 1.2', 'Location': 'Mulund West, Mumbai', 'Price': '₹3.32 lakh', 'Fuel': 'Petrol', 'KM driven': '44,895 km', 'Transmission': 'Manual'}
# Option 284: {'Car Model': '2019 Hyundai VENUE S 1.0 TURBO DCT', 'Location': 'Korum Mall, Thane West', 'Price': '₹6.91 lakh', 'Fuel': 'Petrol', 'KM driven': '46,208 km', 'Transmission': 'Automatic'}
# Option 285: {'Car Model': '2015 Hyundai Grand i10 ASTA AT 1.2 KAPPA VTVT', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹3.17 lakh', 'Fuel': 'Petrol', 'KM driven': '63,637 km', 'Transmission': 'Automatic'}
# Option 286: {'Car Model': '2017 Hyundai Elite i20 ASTA 1.2 (O)', 'Location': 'Thakur Village Kandivali E Mumbai', 'Price': '₹4.54 lakh', 'Fuel': 'Petrol', 'KM driven': '27,186 km', 'Transmission': 'Manual'}
# Option 287: {'Car Model': '2020 Hyundai Creta SX (O) 1.4 TURBO DCT', 'Location': 'Mulund West, Mumbai', 'Price': '₹11.26 lakh', 'Fuel': 'Petrol', 'KM driven': '60,175 km', 'Transmission': 'Automatic'}
# Option 288: {'Car Model': '2015 Hyundai Xcent SX 1.2 (O)', 'Location': 'Korum Mall, Thane West', 'Price': '₹3.45 lakh', 'Fuel': 'Petrol', 'KM driven': '57,407 km', 'Transmission': 'Manual'}
# Option 289: {'Car Model': '2016 Hyundai Grand i10 MAGNA 1.1 CRDI', 'Location': 'Mulund West, Mumbai', 'Price': '₹4.1 lakh', 'Fuel': 'Diesel', 'KM driven': '33,372 km', 'Transmission': 'Manual'}
# Option 290: {'Car Model': '2019 Hyundai NEW SANTRO SPORTZ AMT', 'Location': 'Regency Anantam, Dombivli East', 'Price': '₹4.05 lakh', 'Fuel': 'Petrol', 'KM driven': '56,261 km', 'Transmission': 'Automatic'}
#
# All 291 cars saved to 'hyundai_cars_mumbai.csv'
